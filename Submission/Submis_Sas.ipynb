# %% [raw]
#   Proyek Analisis Data: Bike Sharing Dataset
# - Nama: Sashi kirana salsabila
# - Email: kiranasashi68@gmail.com

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1 :Bagaimana tren peminjaman sepeda per jam dan per hari selama dua tahun (2011 dan 2012)?
# - Pertanyaan 2 : Bagaimana perbandingan antara pengguna kasual dan terdaftar dalam hal jumlah peminjaman sepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv("https://raw.githubusercontent.com/sashiiks/Analisis-Data/main/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df = pd.read_csv("https://raw.githubusercontent.com/sashiiks/Analisis-Data/main/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai Tabel Day

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.nunique()
# Out:
# instant       731
# dteday        731
# season          4
# yr              2
# mnth           12
# holiday         2
# weekday         7
# workingday      2
# weathersit      3
# temp          499
# atemp         690
# hum           595
# windspeed     650
# casual        606
# registered    679
# cnt           696
# dtype: int64

# %%
print("Jumlah duplikasi: ",day_df.duplicated().sum())
day_df.describe()
# Out:
# Jumlah duplikasi:  0
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# Menilai Tabel Hour

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_df.nunique()
# Out:
# instant       17379
# dteday          731
# season            4
# yr                2
# mnth             12
# hr               24
# holiday           2
# weekday           7
# workingday        2
# weathersit        4
# temp             50
# atemp            65
# hum              89
# windspeed        30
# casual          322
# registered      776
# cnt             869
# dtype: int64

# %%
print("Jumlah duplikasi: ",hour_df.duplicated().sum())
hour_df.describe()
# Out:
# Jumlah duplikasi:  0
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Memperbaiki Tipe Data pada day

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  day_df[column] = pd.to_datetime(day_df[column])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
day_df.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0        6           0
# 1        2 2011-01-02       1   0     1        0        0           0
# 2        3 2011-01-03       1   0     1        0        1           1
# 3        4 2011-01-04       1   0     1        0        2           1
# 4        5 2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# Memperbaiki Tipe Data pada Hour

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
hour_df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# Explore Day_df

# %%
day_df.sample(10)
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 288      289 2011-10-16       4   0    10        0        0           0
# 145      146 2011-05-26       2   0     5        0        4           1
# 38        39 2011-02-08       1   0     2        0        2           1
# 421      422 2012-02-26       1   1     2        0        0           0
# 619      620 2012-09-11       3   1     9        0        2           1
# 350      351 2011-12-17       4   0    12        0        6           0
# 476      477 2012-04-21       2   1     4        0        6           0
# 249      250 2011-09-07       3   0     9        0        3           1
# 71        72 2011-03-13       1   0     3        0        0           0
# 86        87 2011-03-28       2   0     3        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 288           1  0.511667  0.503154  0.486667   0.281717    1748        3293
# ...

# %%
day_df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
day_df.describe(include="all")
# Out:
# C:\Users\kiran\AppData\Local\Temp\ipykernel_4512\282069457.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   day_df.describe(include="all")
#            instant               dteday      season          yr        mnth  \
# count   731.000000                  731  731.000000  731.000000  731.000000
# unique         NaN                  731         NaN         NaN         NaN
# top            NaN  2011-01-01 00:00:00         NaN         NaN         NaN
# freq           NaN                    1         NaN         NaN         NaN
# first          NaN  2011-01-01 00:00:00         NaN         NaN         NaN
# last           NaN  2012-12-31 00:00:00         NaN         NaN         NaN
# mean    366.000000                  NaN    2.496580    0.500684    6.519836
# ...

# %%
last_date = day_df['dteday'].max()

# %%
day_df.sample(5)
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 230      231 2011-08-19       3   0     8        0        5           1
# 581      582 2012-08-04       3   1     8        0        6           0
# 209      210 2011-07-29       3   0     7        0        5           1
# 40        41 2011-02-10       1   0     2        0        4           1
# 67        68 2011-03-09       1   0     3        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 230           2  0.685000  0.633221  0.722917   0.139308     797        3356
# 581           1  0.793333  0.751267  0.613333   0.257458    2345        4479
# 209           1  0.838333  0.785967  0.542500   0.174138     670        3176
# 40            1  0.144348  0.149548  0.437391   0.221935      47        1491
# 67            2  0.295833  0.286608  0.775417   0.220150     191        1700
#
#       cnt
# 230  4153
# 581  6824
# 209  3846
# 40   1538
# 67   1891

# %% [markdown]
# Explore Hour_df

# %%
hour_df.sample(10)
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 11770    11771 2012-05-10       2   1     5  15        0        4           1
# 9918      9919 2012-02-23       1   1     2   7        0        4           1
# 16652    16653 2012-12-01       4   1    12  15        0        6           0
# 10277    10278 2012-03-09       1   1     3   7        0        5           1
# 5254      5255 2011-08-11       3   0     8  20        0        4           1
# 9920      9921 2012-02-23       1   1     2   9        0        4           1
# 1071      1072 2011-02-17       1   0     2   9        0        4           1
# 16952    16953 2012-12-14       4   1    12   3        0        5           1
# 13018    13019 2012-07-01       3   1     7  15        0        0           0
# 3938      3939 2011-06-18       2   0     6   0        0        6           0
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
hour_df.describe(include="all")
# Out:
# C:\Users\kiran\AppData\Local\Temp\ipykernel_4512\1264340832.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   hour_df.describe(include="all")
#            instant               dteday        season            yr  \
# count   17379.0000                17379  17379.000000  17379.000000
# unique         NaN                  731           NaN           NaN
# top            NaN  2011-01-01 00:00:00           NaN           NaN
# freq           NaN                   24           NaN           NaN
# first          NaN  2011-01-01 00:00:00           NaN           NaN
# last           NaN  2012-12-31 00:00:00           NaN           NaN
# mean     8690.0000                  NaN      2.501640      0.502561
# std      5017.0295                  NaN      1.106918      0.500008
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# Bagaimana tren peminjaman sepeda per jam dan per hari selama dua tahun (2011 dan 2012)?

# %%
plt.figure(figsize=(14, 6))
plt.plot(
    day_df['dteday'], 
    day_df['cnt'], 
    label='Peminjaman per Hari', 
    marker='o')
plt.title('Tren Peminjaman Sepeda per Hari (2011-2012)')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Peminjaman Sepeda')
plt.legend()
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# Bagaimana perbandingan antara pengguna kasual dan terdaftar dalam hal jumlah peminjaman sepeda?

# %%
plt.figure(figsize=(14, 6))
plt.bar(
    day_df['dteday'], 
    day_df['casual'], 
    label='Kasual', 
    color='blue', 
    alpha=0.7)
plt.bar(
    day_df['dteday'], 
    day_df['registered'], 
    bottom=day_df['casual'], 
    label='Terdaftar', 
    color='orange', 
    alpha=0.7)
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Peminjaman Sepeda')
plt.title('Perbandingan Peminjaman Sepeda antara Pengguna Kasual dan Terdaftar')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1 : Berdasarkan plot yang di tampilkan Terlihat bahwa ada variasi jumlah peminjaman sepeda per hari selama dua tahun tersebut. Pola tren menunjukkan kenaikan dan penurunan tertentu dari waktu ke waktu. lalu Dengan melihat garis tren, kita dapat melihat apakah ada tren umum peminjaman sepeda selama dua tahun. Jika garis cenderung naik, itu bisa menunjukkan peningkatan popularitas penggunaan sepeda. Sebaliknya, jika garis cenderung turun, itu bisa menunjukkan penurunan popularitas. Dan itu terbukti di 2012 tren peminjaman sepeda mengalami kenaikan setiap harinya hingga pertengahan tahun dan mengalami sedikit penurunan di akhir tahun menuju 2013.
# - Conclution pertanyaan 2 : berdasarkan diagram di atas, perbandingan untuk penguna kasual dan terdaftar itu sangat berbeda jauh dan lebih banyak yang melakukan peminjaman dari pengguna terdaftar dibanding kasual. perbandingan ini cukup signifikan dan jumlahnya pun jauh berbeda.

# %%
day_df.to_csv("day_data.csv", index=False)

# %%
hour_df.to_csv("hour_data.csv", index=False)
